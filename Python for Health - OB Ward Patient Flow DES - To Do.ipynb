# %% [markdown]
# # Python for Health - OB Ward Patient Flow DES Model
#
# The following respresents a simple patient flow model for expectant mothers processes through Labor and Delivery in an in-hospital setting.
#
# Such models can be incredibly helpful for modeling resource demand overtime, determining capacity and resource stretch, identifying process chokepoints and potential hazards.
#
# Some specific Details:
#
# - We will generate patient arrivals via a Poisson process
# - Uses one Resource objects to model Observation (OBS) beds, Labor anr Deliver (LDR), and Post-Partum Recorvery (PP).
# - Arrival rates and mean lengths of stay hard coded as constants. These statistics can be calculated based on hospital stats
# - We also have encoded an arrival generator (initial delay and arrival stop time).

# %%
# Libraries to import
# NOTE: SimPy is not included in anaconda and will need to be installed
# before this notebook can be run
import simpy
import numpy as np
from numpy.random import RandomState

# %% [markdown]
# We will now assign a set of model parameters. Generally we will need to specify our overall model capacity as well as our resource utilization rate, where capacity is measured in terms of beds and utilization rate is determined in terms of hours

# %%
# We now need to assign model parameters
# This first set of parameters will define our utilization rate (in hours)
ARR_RATE = 0.5      # Arrivals per hour
MEAN_LOS_OBS = 4    # Mean length of stay
MEAN_LOS_LDR = 10
MEAN_LOS_PP = 48

# Defining the size of our OB ward in terms of beds
CAPACITY_OBS = 2
CAPACITY_LDR = 4
CAPACITY_PP = 40

# Seed parameter for our randomizer
RNG_SEED = 6353

# %% [markdown]
# We will now create a series of helper functions that will create the rules for how our patients will migrate through the simulation.
#
# The first is a patient generator model. This function will create the rules governing patient demand for services in our model.
#
# Here we will use our predetermined parameters to model that demand by  generating patients according to a simple Poisson process
#
#         Parameters
#         ----------
#         env : simpy.Environment
#             the simulation environment
#         arr_rate : float
#             exponential arrival rate
#         initial_delay: float (default 0)
#             time before arrival generation should begin
#         stoptime: float (default Infinity)
#             time after which no arrivals are generated
#         prng : RandomState object
#                Seeded RandomState object for generating pseudo-random numbers.
#
# See [here](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.RandomState.html) for more details.

# %%
def patient_generator(env, arr_stream, arr_rate, initial_delay=0,
                      stoptime=simpy.core.Infinity, prng=RandomState(0)):
# ongoing count of patients created
    patients_created = 0

    # Yield for the initial delay
    yield env.timeout(initial_delay)

    # Generate arrivals as long as simulation time is before stoptime
    while env.now < stoptime:

        iat = prng.exponential(1.0 / arr_rate)

        # Sample los distributions
        los_obs = prng.exponential(MEAN_LOS_OBS)
        los_ldr = prng.exponential(MEAN_LOS_LDR)
        los_pp = prng.exponential(MEAN_LOS_PP)


        # Create new patient process instance
        patients_created += 1
        obp = obpatient_flow(env, 'Patient{}'.format(patients_created),
                             los_obs=los_obs, los_ldr=los_ldr, los_pp=los_pp)

        env.process(obp)

        # Compute next interarrival time

        yield env.timeout(iat)

# %% [markdown]
# Our next helper function has to establish the rules governing how a patient transits through the L&D process.
#
# This Process function will model how a patient flows through system.
#
#         Parameters
#         ----------
#         env : simpy.Environment
#             the simulation environment
#         name : str
#             process instance id
#         los_obs : float
#             length of stay in OBS unit
#         los_ldr : float
#             length of stay in LDR unit
#         los_pp : float
#             length of stay in PP unit
# The function will print status updates of a patient as she progresses through our process flow.
#
# The function is designed to allow a patient to request, acquire, and then release a resource (bed) as she migrates through each step in our process.
#
# Times to request are based on the patient generator function previosly generated.
#
# Beds are allocated the moment they are available and requested. If there is a discrepency between bed requested and bed acquired, that time is noted as wait time.

# %%
def obpatient_flow(env, name, los_obs, los_ldr, los_pp):

    # Note the repetitive code and the use of separate request objects for each
    # stay in the different units.

    # OBS
    print("{} trying to get OBS at {:.4f}".format(name, env.now))
    bed_request_ts = env.now
    bed_request1 = obs_unit.request() # Request an OBS bed
    yield bed_request1
    print("{} entering OBS at {:.4f}".format(name, env.now))
    # this line is critical for calculating delays. If there is a
    # discrepancy between now (when the bed is released), and
    # when requested, we compute as a wait.
    if env.now > bed_request_ts:
        print("{} waited {:.4f} time units for OBS bed".format(name, env.now-  bed_request_ts))
    yield env.timeout(los_obs) # Stay in obs bed

    print("{} trying to get LDR at {:.4f}".format(name, env.now))
    bed_request_ts = env.now
    bed_request2 = ldr_unit.request()  # Request an LDR bed
    yield bed_request2

    # Got LDR bed, release OBS bed
    obs_unit.release(bed_request1)  # Release the OBS bed
    print("{} leaving OBS at {}".format(name, env.now))

    # LDR stay
    print("{} entering LDR at {:.4f}".format(name, env.now))
    if env.now > bed_request_ts:
        print("{} waited {:.4f} time units for LDR bed".format(name, env.now - bed_request_ts))
    yield env.timeout(los_ldr) # Stay in LDR bed

    print("{} trying to get PP at {:.4f}".format(name, env.now))
    bed_request_ts = env.now
    bed_request3 = pp_unit.request()  # Request a PP bed
    yield bed_request3

    # Got PP bed, release LDR bed
    ldr_unit.release(bed_request2)  # Release the obs bed
    print("{} leaving LDR at {:.4f}".format(name, env.now))

    # PP stay
    print("{} entering PP at {:.4f}".format(name, env.now))
    if env.now > bed_request_ts:
        print("{} waited {:.4f} time units for PP bed".format(name, env.now - bed_request_ts))
    yield env.timeout(los_pp) # Stay in PP bed
    pp_unit.release(bed_request3)  # Release the PP bed

    print("{} leaving PP and system at {:.4f}".format(name, env.now))

# %%
# Initialize a simulation environment
env = simpy.Environment()
prng = RandomState(RNG_SEED)

# %%
# Declare Resources to model all units
obs_unit = simpy.Resource(env, CAPACITY_OBS)
ldr_unit = simpy.Resource(env, CAPACITY_LDR)
pp_unit = simpy.Resource(env, CAPACITY_PP)

# %%
# Run the simulation for a while. Let's shut arrivals off after 50 time units.
runtime = 75
stop_arrivals = 50
env.process(patient_generator(env, "Type1", ARR_RATE, 0, stop_arrivals, prng))
env.run(until=runtime)
# Out:
# Patient1 trying to get OBS at 0.0000
# Patient1 entering OBS at 0.0000
# Patient1 trying to get LDR at 0.4633
# Patient1 leaving OBS at 0.46331881194020585
# Patient1 entering LDR at 0.4633
# Patient2 trying to get OBS at 3.0135
# Patient2 entering OBS at 3.0135
# Patient3 trying to get OBS at 4.5152
# Patient3 entering OBS at 4.5152
# Patient1 trying to get PP at 5.2945
# Patient1 leaving LDR at 5.2945
# Patient1 entering PP at 5.2945
# Patient4 trying to get OBS at 5.8100
# Patient5 trying to get OBS at 7.1863
# Patient3 trying to get LDR at 11.4085
# Patient3 leaving OBS at 11.408544063725351
# Patient3 entering LDR at 11.4085
# Patient4 entering OBS at 11.4085
# Patient4 waited 5.5986 time units for OBS bed
# Patient4 trying to get LDR at 11.4819
# Patient4 leaving OBS at 11.481906392223179
# Patient4 entering LDR at 11.4819
# Patient5 entering OBS at 11.4819
# Patient5 waited 4.2956 time units for OBS bed
# Patient4 trying to get PP at 11.9536
# Patient4 leaving LDR at 11.9536
# Patient4 entering PP at 11.9536
# Patient6 trying to get OBS at 13.4522
# Patient7 trying to get OBS at 14.2990
# Patient8 trying to get OBS at 14.9725
# Patient2 trying to get LDR at 15.1990
# Patient2 leaving OBS at 15.199024871698343
# Patient2 entering LDR at 15.1990
# Patient6 entering OBS at 15.1990
# Patient6 waited 1.7468 time units for OBS bed
# Patient9 trying to get OBS at 16.3930
# Patient6 trying to get LDR at 18.7608
# Patient6 leaving OBS at 18.760830145249876
# Patient6 entering LDR at 18.7608
# Patient7 entering OBS at 18.7608
# Patient7 waited 4.4619 time units for OBS bed
# Patient7 trying to get LDR at 19.0609
# Patient7 leaving OBS at 19.060903870538535
# Patient7 entering LDR at 19.0609
# Patient8 entering OBS at 19.0609
# Patient8 waited 4.0884 time units for OBS bed
# Patient7 trying to get PP at 19.0896
# Patient7 leaving LDR at 19.0896
# Patient7 entering PP at 19.0896
# Patient10 trying to get OBS at 21.4950
# Patient5 trying to get LDR at 22.0973
# Patient5 leaving OBS at 22.097316563642913
# Patient5 entering LDR at 22.0973
# Patient9 entering OBS at 22.0973
# Patient9 waited 5.7043 time units for OBS bed
# Patient11 trying to get OBS at 22.1501
# Patient8 trying to get LDR at 24.5675
# Patient12 trying to get OBS at 25.1898
# Patient13 trying to get OBS at 25.5985
# Patient2 trying to get PP at 25.9312
# Patient2 leaving LDR at 25.9312
# Patient2 entering PP at 25.9312
# Patient8 leaving OBS at 25.931246054936103
# Patient8 entering LDR at 25.9312
# Patient8 waited 1.3637 time units for LDR bed
# Patient10 entering OBS at 25.9312
# Patient10 waited 4.4363 time units for OBS bed
# Patient6 trying to get PP at 26.1148
# Patient6 leaving LDR at 26.1148
# Patient6 entering PP at 26.1148
# Patient8 trying to get PP at 26.2167
# Patient8 leaving LDR at 26.2167
# Patient8 entering PP at 26.2167
# Patient14 trying to get OBS at 26.8318
# Patient10 trying to get LDR at 26.9472
# Patient10 leaving OBS at 26.94723158596716
# Patient10 entering LDR at 26.9472
# Patient11 entering OBS at 26.9472
# Patient11 waited 4.7971 time units for OBS bed
# Patient5 trying to get PP at 28.4474
# Patient5 leaving LDR at 28.4474
# Patient5 entering PP at 28.4474
# Patient15 trying to get OBS at 28.4875
# Patient16 trying to get OBS at 29.2104
# Patient17 trying to get OBS at 29.2295
# Patient11 trying to get LDR at 30.6507
# Patient11 leaving OBS at 30.6506634365843
# Patient11 entering LDR at 30.6507
# Patient12 entering OBS at 30.6507
# Patient12 waited 5.4609 time units for OBS bed
# Patient11 trying to get PP at 30.6903
# Patient11 leaving LDR at 30.6903
# Patient11 entering PP at 30.6903
# Patient12 trying to get LDR at 31.6219
# Patient12 leaving OBS at 31.621901115403777
# Patient12 entering LDR at 31.6219
# Patient13 entering OBS at 31.6219
# Patient13 waited 6.0234 time units for OBS bed
# Patient18 trying to get OBS at 31.7426
# Patient13 trying to get LDR at 32.2914
# Patient13 leaving OBS at 32.29143980233062
# Patient13 entering LDR at 32.2914
# Patient14 entering OBS at 32.2914
# Patient14 waited 5.4596 time units for OBS bed
# Patient19 trying to get OBS at 33.7528
# Patient12 trying to get PP at 34.0894
# Patient12 leaving LDR at 34.0894
# Patient12 entering PP at 34.0894
# Patient7 leaving PP and system at 34.5312
# Patient13 trying to get PP at 35.1196
# Patient13 leaving LDR at 35.1196
# Patient13 entering PP at 35.1196
# Patient9 trying to get LDR at 35.3367
# Patient9 leaving OBS at 35.33673781841098
# Patient9 entering LDR at 35.3367
# Patient15 entering OBS at 35.3367
# Patient15 waited 6.8492 time units for OBS bed
# Patient20 trying to get OBS at 35.7432
# Patient15 trying to get LDR at 36.6575
# Patient15 leaving OBS at 36.65750307212039
# Patient15 entering LDR at 36.6575
# Patient16 entering OBS at 36.6575
# Patient16 waited 7.4471 time units for OBS bed
# Patient21 trying to get OBS at 37.3070
# Patient16 trying to get LDR at 37.7887
# Patient11 leaving PP and system at 38.2921
# Patient10 trying to get PP at 39.3492
# Patient10 leaving LDR at 39.3492
# Patient10 entering PP at 39.3492
# Patient16 leaving OBS at 39.34915515313968
# Patient16 entering LDR at 39.3492
# Patient16 waited 1.5605 time units for LDR bed
# Patient17 entering OBS at 39.3492
# Patient17 waited 10.1197 time units for OBS bed
# Patient3 trying to get PP at 39.8289
# Patient3 leaving LDR at 39.8289
# Patient3 entering PP at 39.8289
# Patient22 trying to get OBS at 39.9746
# Patient16 trying to get PP at 41.2534
# Patient16 leaving LDR at 41.2534
# Patient16 entering PP at 41.2534
# Patient23 trying to get OBS at 41.5328
# Patient1 leaving PP and system at 42.0130
# Patient24 trying to get OBS at 42.2725
# Patient14 trying to get LDR at 42.3532
# Patient14 leaving OBS at 42.353235085857676
# Patient14 entering LDR at 42.3532
# Patient18 entering OBS at 42.3532
# Patient18 waited 10.6106 time units for OBS bed
# Patient17 trying to get LDR at 42.7193
# Patient17 leaving OBS at 42.71929047558235
# Patient17 entering LDR at 42.7193
# Patient19 entering OBS at 42.7193
# Patient19 waited 8.9665 time units for OBS bed
# Patient15 trying to get PP at 43.3319
# Patient15 leaving LDR at 43.3319
# Patient15 entering PP at 43.3319
# Patient9 trying to get PP at 43.9133
# Patient9 leaving LDR at 43.9133
# Patient9 entering PP at 43.9133
# Patient25 trying to get OBS at 43.9914
# Patient18 trying to get LDR at 46.0082
# Patient18 leaving OBS at 46.00816255629812
# Patient18 entering LDR at 46.0082
# Patient20 entering OBS at 46.0082
# Patient20 waited 10.2650 time units for OBS bed
# Patient17 trying to get PP at 46.1923
# Patient17 leaving LDR at 46.1923
# Patient17 entering PP at 46.1923
# Patient20 trying to get LDR at 46.7974
# Patient20 leaving OBS at 46.79737201849263
# Patient20 entering LDR at 46.7974
# Patient21 entering OBS at 46.7974
# Patient21 waited 9.4903 time units for OBS bed
# Patient18 trying to get PP at 47.4520
# Patient18 leaving LDR at 47.4520
# Patient18 entering PP at 47.4520
# Patient21 trying to get LDR at 48.4559
# Patient21 leaving OBS at 48.45592554829763
# Patient21 entering LDR at 48.4559
# Patient22 entering OBS at 48.4559
# Patient22 waited 8.4813 time units for OBS bed
# Patient26 trying to get OBS at 48.8133
# Patient14 trying to get PP at 49.2695
# Patient14 leaving LDR at 49.2695
# Patient14 entering PP at 49.2695
# Patient22 trying to get LDR at 49.4229
# Patient22 leaving OBS at 49.422868634444875
# Patient22 entering LDR at 49.4229
# Patient23 entering OBS at 49.4229
# Patient23 waited 7.8901 time units for OBS bed
# Patient27 trying to get OBS at 49.9159
# Patient21 trying to get PP at 50.8053
# Patient21 leaving LDR at 50.8053
# Patient21 entering PP at 50.8053
# Patient19 trying to get LDR at 51.4673
# Patient19 leaving OBS at 51.46727744550687
# Patient19 entering LDR at 51.4673
# Patient24 entering OBS at 51.4673
# Patient24 waited 9.1948 time units for OBS bed
# Patient24 trying to get LDR at 52.1528
# Patient24 leaving OBS at 52.15280746917521
# Patient24 entering LDR at 52.1528
# Patient25 entering OBS at 52.1528
# Patient25 waited 8.1614 time units for OBS bed
# Patient19 trying to get PP at 52.3187
# Patient19 leaving LDR at 52.3187
# Patient19 entering PP at 52.3187
# Patient23 trying to get LDR at 53.4934
# Patient23 leaving OBS at 53.49342856759677
# Patient23 entering LDR at 53.4934
# Patient26 entering OBS at 53.4934
# Patient26 waited 4.6802 time units for OBS bed
# Patient26 trying to get LDR at 53.6211
# Patient24 trying to get PP at 53.8002
# Patient24 leaving LDR at 53.8002
# Patient24 entering PP at 53.8002
# Patient26 leaving OBS at 53.80017580740925
# Patient26 entering LDR at 53.8002
# Patient26 waited 0.1791 time units for LDR bed
# Patient27 entering OBS at 53.8002
# Patient27 waited 3.8843 time units for OBS bed
# Patient27 trying to get LDR at 55.3017
# Patient20 trying to get PP at 55.5052
# Patient20 leaving LDR at 55.5052
# Patient20 entering PP at 55.5052
# Patient27 leaving OBS at 55.50521750315505
# Patient27 entering LDR at 55.5052
# Patient27 waited 0.2035 time units for LDR bed
# Patient23 trying to get PP at 55.8627
# Patient23 leaving LDR at 55.8627
# Patient23 entering PP at 55.8627
# Patient22 trying to get PP at 55.9596
# Patient22 leaving LDR at 55.9596
# Patient22 entering PP at 55.9596
# Patient10 leaving PP and system at 56.6492
# Patient12 leaving PP and system at 57.3092
# Patient26 trying to get PP at 57.4632
# Patient26 leaving LDR at 57.4632
# Patient26 entering PP at 57.4632
# Patient16 leaving PP and system at 57.5638
# Patient18 leaving PP and system at 60.0183
# Patient25 trying to get LDR at 63.4530
# Patient25 leaving OBS at 63.452956860151694
# Patient25 entering LDR at 63.4530
# Patient27 trying to get PP at 63.6275
# Patient27 leaving LDR at 63.6275
# Patient27 entering PP at 63.6275
# Patient9 leaving PP and system at 63.6874
# Patient23 leaving PP and system at 63.9996
# Patient5 leaving PP and system at 65.4926
# Patient25 trying to get PP at 67.6970
# Patient25 leaving LDR at 67.6970
# Patient25 entering PP at 67.6970
# Patient15 leaving PP and system at 69.2773
# Patient22 leaving PP and system at 69.6960
# Patient14 leaving PP and system at 69.8530
# Patient17 leaving PP and system at 71.8851
# Patient25 leaving PP and system at 72.7674
# Patient20 leaving PP and system at 73.1925

# %% [markdown]
# This represents a final runthrough of our patient flow system. As possible extensions we can begin to calculate metrics like average waittimes at each segment, min, max, and spread, average resource utilization etc.
